# %% [markdown]
# # Import and Handling Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("C:\\Users\\nikhi\\OneDrive\\Desktop\\Social Prachar\\Excel files\\Data Processing and Stats.csv")
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5  France   35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# No of rows
len(data)
# Out:
# 10

# %%
# No of columns
len(data.columns)
# Out:
# 4

# %%
# To read/access the column in the data set
data["Country"]
# Out:
# 0     France
# 1      Spain
# 2    Germany
# 3      Spain
# 4    Germany
# 5    France
# 6      Spain
# 7     France
# 8    Germany
# 9     France
# Name: Country, dtype: object

# %%
data.head(3)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No

# %%
data.tail(3)
# Out:
#    Country   Age   Salary Purchased
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.columns
# Out:
# Index(['Country', 'Age', 'Salary', 'Purchased'], dtype='object')

# %%
data.shape
# Out:
# (10, 4)

# %%
data.values
# Out:
# array([['France', 44.0, 72000.0, 'No'],
#        ['Spain', 27.0, 48000.0, 'Yes'],
#        ['Germany', 30.0, 54000.0, 'No'],
#        ['Spain', 38.0, 61000.0, 'No'],
#        ['Germany', 40.0, nan, 'Yes'],
#        ['France ', 35.0, 58000.0, 'Yes'],
#        ['Spain', nan, 52000.0, 'No'],
#        ['France', 48.0, 79000.0, 'Yes'],
#        ['Germany', 50.0, 83000.0, 'No'],
#        ['France', 37.0, 67000.0, 'Yes']], dtype=object)

# %%
data.dtypes
# Out:
# Country       object
# Age          float64
# Salary       float64
# Purchased     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %%
data.info
# Out:
# <bound method DataFrame.info of    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5  France   35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes>

# %%
# Data Selection
# Pandas has a different data access methods
# As usual we use indexing operators "[]" and attribute operator "." for quick and easy access
# .loc() which is for label based indexing can search values based on values
# .iloc() which is for integer based can search value based on indexing
# Syntax- file[row,column]

# %%
data.loc[0,"Salary"]
# Out:
# 72000.0

# %%
data.loc[data["Purchased"]=="Yes"]
# Out:
#    Country   Age   Salary Purchased
# 1    Spain  27.0  48000.0       Yes
# 4  Germany  40.0      NaN       Yes
# 5  France   35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 9   France  37.0  67000.0       Yes

# %%
data.loc[data["Purchased"]=="No"]
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 6    Spain   NaN  52000.0        No
# 8  Germany  50.0  83000.0        No

# %%
x = data.iloc[:, :-1].values
x
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, nan],
#        ['France ', 35.0, 58000.0],
#        ['Spain', nan, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
# To identify the missing values, True means we have missing values in the data/column
data.isnull()
# Out:
#    Country    Age  Salary  Purchased
# 0    False  False   False      False
# 1    False  False   False      False
# 2    False  False   False      False
# 3    False  False   False      False
# 4    False  False    True      False
# 5    False  False   False      False
# 6    False   True   False      False
# 7    False  False   False      False
# 8    False  False   False      False
# 9    False  False   False      False

# %%
# True mean missing value and False means no missing value
data.isnull().any()
# Out:
# Country      False
# Age           True
# Salary        True
# Purchased    False
# dtype: bool

# %%
# To count the no of missing values columnwise
data.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
data
# del data['Column']- to delete column from the data
# Out:
#     Age   Salary Purchased
# 0  44.0  72000.0        No
# 1  27.0  48000.0       Yes
# 2  30.0  54000.0        No
# 3  38.0  61000.0        No
# 4  40.0      NaN       Yes
# 5  35.0  58000.0       Yes
# 6   NaN  52000.0        No
# 7  48.0  79000.0       Yes
# 8  50.0  83000.0        No
# 9  37.0  67000.0       Yes

# %%
# To del row from the data
data.drop(0)
# Out:
#     Age   Salary Purchased
# 1  27.0  48000.0       Yes
# 2  30.0  54000.0        No
# 3  38.0  61000.0        No
# 4  40.0      NaN       Yes
# 5  35.0  58000.0       Yes
# 6   NaN  52000.0        No
# 7  48.0  79000.0       Yes
# 8  50.0  83000.0        No
# 9  37.0  67000.0       Yes

# %%
# To remove the columns
data.drop("Age", axis=1, inplace=True)

# %%
data
# Out:
#     Salary Purchased
# 0  72000.0        No
# 1  48000.0       Yes
# 2  54000.0        No
# 3  61000.0        No
# 4      NaN       Yes
# 5  58000.0       Yes
# 6  52000.0        No
# 7  79000.0       Yes
# 8  83000.0        No
# 9  67000.0       Yes

# %%
data = pd.read_csv("C:\\Users\\nikhi\\OneDrive\\Desktop\\Social Prachar\\Excel files\\Data Processing and Stats.csv")
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5  France   35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.drop("Age", axis=1, inplace=True)
data
# Out:
#    Country   Salary Purchased
# 0   France  72000.0        No
# 1    Spain  48000.0       Yes
# 2  Germany  54000.0        No
# 3    Spain  61000.0        No
# 4  Germany      NaN       Yes
# 5  France   58000.0       Yes
# 6    Spain  52000.0        No
# 7   France  79000.0       Yes
# 8  Germany  83000.0        No
# 9   France  67000.0       Yes

# %%
data = pd.read_csv("C:\\Users\\nikhi\\OneDrive\\Desktop\\Social Prachar\\Excel files\\Data Processing and Stats.csv")
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5  France   35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# Replace the missing values with the given value
data.fillna(16)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0     16.0       Yes
# 5  France   35.0  58000.0       Yes
# 6    Spain  16.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# To remove the complete rows which have missing values
data.dropna()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5  France   35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data = pd.read_csv("C:\\Users\\nikhi\\OneDrive\\Desktop\\Social Prachar\\Excel files\\Data Processing and Stats.csv")
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5  France   35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# To remove columns with missing data
data.dropna(axis=1)
# Out:
#    Country Purchased
# 0   France        No
# 1    Spain       Yes
# 2  Germany        No
# 3    Spain        No
# 4  Germany       Yes
# 5  France        Yes
# 6    Spain        No
# 7   France       Yes
# 8  Germany        No
# 9   France       Yes

# %%
data = pd.read_csv("C:\\Users\\nikhi\\OneDrive\\Desktop\\Social Prachar\\Excel files\\Data Processing and Stats.csv")
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5  France   35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# To replace the missing values with mean/median of the columns in the entire dataset
data.fillna(data.mean(), inplace=True)
data
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5  France   35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
data = pd.read_csv("C:\\Users\\nikhi\\OneDrive\\Desktop\\Social Prachar\\Excel files\\Data Processing and Stats.csv")
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5  France   35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# To replace the missing values with mean/median in specified individual columns
data['Age'].fillna(data['Age'].mean(),inplace=True)
data
# Out:
#    Country        Age   Salary Purchased
# 0   France  44.000000  72000.0        No
# 1    Spain  27.000000  48000.0       Yes
# 2  Germany  30.000000  54000.0        No
# 3    Spain  38.000000  61000.0        No
# 4  Germany  40.000000      NaN       Yes
# 5  France   35.000000  58000.0       Yes
# 6    Spain  38.777778  52000.0        No
# 7   France  48.000000  79000.0       Yes
# 8  Germany  50.000000  83000.0        No
# 9   France  37.000000  67000.0       Yes

# %%
data['Salary'].fillna(data['Salary'].mean(),inplace=True)
data
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5  France   35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes
